# %%
display(dbutils.fs.ls('dbfs:/databricks-datasets/COVID/covid-19-data/'))

# %%
# %sql

# %%
df = spark.readstream.format("cloudfiles").option("cloudFiles.format", "csv").option("cloudFiles.schemaHints", "date string,")

# %%
df_covid_states = spark.read.csv('dbfs:/databricks-datasets/COVID/covid-19-data/us-states.csv', header=True)

# %%
df_covid_states.display()

# %%
df_covid_states = spark.read.csv('dbfs:/databricks-datasets/COVID/covid-19-data/us-states.csv', header=True)
rows = df_covid_states.limit(10).collect()
for row in rows:
    print(row)

# %%
df_covid_az = df_covid_states.filter(
    (df_covid_states['state'] == 'Arizona') & 
    (df_covid_states['deaths'] != '0')
)
display(df_covid_az)

# %%
display(df_covid_states)

# %%
df_covid_counties = spark.read.csv('dbfs:/databricks-datasets/COVID/covid-19-data/us-counties.csv', header=True)
df_covid_counties.write.mode('overwrite').saveAsTable('covid_counties')

# %%
# %sql
SELECT * FROM covid_counties
